# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", "src"))
if project_root not in sys.path:
    sys.path.append(project_root)
from eda import procesador_EDA
from eda.procesador_EDA import ProcesadorEDA
from datos.GestorDatos import GestorDatos
from visualizacion.visualizacion import Visualizador
# Out:
# ['SQL Server', 'SQL Server Native Client 11.0', 'ODBC Driver 17 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)', 'PostgreSQL ODBC Driver(ANSI)', 'PostgreSQL ODBC Driver(UNICODE)']

# %%
GestorDatos = GestorDatos()

df = GestorDatos.ObtencionPasajerosTrenUrbano()
visu = Visualizador(df)
# Out:
# 2025-08-20 15:08:40,079 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-08-20 15:08:40,080 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-20 15:08:40,083 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-08-20 15:08:40,083 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-20 15:08:40,086 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-08-20 15:08:40,086 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-20 15:08:40,088 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-20 15:08:40,092 INFO sqlalchemy.engine.Engine COMMIT
# 2025-08-20 15:08:40,092 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-20 15:08:40,094 INFO sqlalchemy.engine.Engine COMMIT
# 2025-08-20 15:08:40,101 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-20 15:08:40,103 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# ...

# %%
df.columns
# Out:
# Index(['id', 'codigoruta', 'descripcionruta', 'codigorecorrido',
#        'descripcionrecorrido', 'sentido', 'dia', 'mes', 'annio',
#        'cantidadpasajerosreg', 'cantidadadultosmay', 'ingresos'],
#       dtype='object')

# %%
visu.mostrar_histograma('cantidadpasajerosreg')

# %%
visu.mostrar_scatter('cantidadpasajerosreg','cantidadadultosmay')

# %%
visu.mostrar_grafico_barras('mes')

# %%
visu.mostrar_barras_horizontal('annio')
